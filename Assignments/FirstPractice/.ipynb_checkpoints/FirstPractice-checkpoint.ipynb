# %% [markdown]
# # Practice 1.
# ##  Objectives:
# 1. Learn to load data and analyse the properties.
#
# 2. Do a simple exploratory data analysis
# 3. Learn the **data cleaning and visualitzation** features of Pandas.
# ## Aplication:
# Data basse: Data set from the UCI Machine Learning Repository
# (http://archive.ics.uci.edu/ml)
# 1.   Cars data: http://archive.ics.uci.edu/ml/datasets/Automobile.
# - Predict **price** in dollars.
#
# 2. Database: Wine quality, http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# - Predict **quality** (score between 0 and 10)

# %% [markdown]
# ___________________________________

# %% [markdown]
# ## First we load the Libraries
# * Pandas: For dealing with tabulated data: excel + sql
# * sklearn: Machine learning framework
# * os: anciliary functions for dealing with the operating system

# %%
import pandas as pd
import sklearn
import os

# %% [markdown]
# ### Use the os library for generating the path to the file

# %%
File = "Bdcars.csv"
Filename = os.path.join(os.getcwd(),'Data',File)
print(f'Filename with path: \n {Filename}')
# Out:
# Filename with path:
#  C:\Users\raulc\Desktop\Master\Q2\ML\FirstPractice\Data\Bdcars.csv

# %% [markdown]
# ### First rows of the file
# **make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price**
#
# alfa-romero,gas,std,two,convertible,rwd,front,88.60,168.80,64.10,48.80,2548,dohc,four,130,mpfi,3.47,2.68,9.00,111,5000,21,27,13495
#
# alfa-romero,gas,std,two,convertible,rwd,front,88.60,168.80,64.10,48.80,2548,dohc,four,130,mpfi,3.47,2.68,9.00,111,5000,21,27,16500
#
# alfa-romero,gas,std,two,hatchback,rwd,front,94.50,171.20,65.50,52.40,2823,ohcv,six,152,mpfi,2.68,3.47,9.00,154,5000,19,26,16500

# %% [markdown]
# ### Load the data by means of Pandas
# - Note that the structure is a csv: Comma separated values
# - The library recognizes the first line as the name of the columns
# - Note the similarity with an *excel file*

# %% [markdown]
# #  See Appendix for  the meaning of the variables.

# %%
Data = pd.read_csv(Filename)
Data.head()
# Out:
#           make  fuel-type  aspiration  num-of-doors   body-style  \
# 0  alfa-romero        gas         std           two  convertible
# 1  alfa-romero        gas         std           two  convertible
# 2  alfa-romero        gas         std           two    hatchback
# 3         audi        gas         std          four        sedan
# 4         audi        gas         std          four        sedan
#
#    drive-wheels  engine-location   wheel-base   length   width  ...  \
# 0           rwd            front         88.6    168.8    64.1  ...
# 1           rwd            front         88.6    168.8    64.1  ...
# 2           rwd            front         94.5    171.2    65.5  ...
# 3           fwd            front         99.8    176.6    66.2  ...
# 4           4wd            front         99.4    176.6    66.4  ...
#
#     engine-size   fuel-system  bore  stroke   compression-ratio  horsepower  \
# 0           130          mpfi  3.47    2.68                 9.0         111
# ...

# %%
print(f'Size of the database: {Data.shape} (rows X columns)')
# Out:
# Size of the database: (205, 24) (rows X columns)

# %% [markdown]
# ## Deal with the Excel table as a Matrix => Transpose

# %%
Data.T.head(24)
# Out:
#                             0            1            2      3      4    \
#  make               alfa-romero  alfa-romero  alfa-romero   audi   audi
#  fuel-type                  gas          gas          gas    gas    gas
#  aspiration                 std          std          std    std    std
#  num-of-doors               two          two          two   four   four
#  body-style         convertible  convertible    hatchback  sedan  sedan
#  drive-wheels               rwd          rwd          rwd    fwd    4wd
#  engine-location          front        front        front  front  front
#  wheel-base                88.6         88.6         94.5   99.8   99.4
#  length                   168.8        168.8        171.2  176.6  176.6
#  width                     64.1         64.1         65.5   66.2   66.4
#  height                    48.8         48.8         52.4   54.3   54.3
#  curb-weight               2548         2548         2823   2337   2824
# ...

# %% [markdown]
# ## First approximation to the Exploratory Data Analysis
# ###  Summary of the descriptive statitistics
# Note that only affects the numerical values

# %%
Data.describe().T.round(2)
# Out:
#                     count     mean     std     min     25%     50%     75%  \
#  wheel-base         205.0    98.76    6.02    86.6    94.5    97.0   102.4
#  length             205.0   174.05   12.34   141.1   166.3   173.2   183.1
#  width              205.0    65.91    2.15    60.3    64.1    65.5    66.9
#  height             205.0    53.72    2.44    47.8    52.0    54.1    55.5
#  curb-weight        205.0  2555.57  520.68  1488.0  2145.0  2414.0  2935.0
#  engine-size        205.0   126.91   41.64    61.0    97.0   120.0   141.0
#  compression-ratio  205.0    10.14    3.97     7.0     8.6     9.0     9.4
#  city-mpg           205.0    25.22    6.54    13.0    19.0    24.0    30.0
#  highway-mpg        205.0    30.75    6.89    16.0    25.0    30.0    34.0
#
#                        max
#  wheel-base          120.9
#  length              208.1
#  width                72.3
#  height               59.8
#  curb-weight        4066.0
#  engine-size         326.0
# ...

# %% [markdown]
# ## IMPORTANT: seems there is a problem with price
# Price is not **float**  but is **object!**

# %%
Data[' price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name:  price, Length: 205, dtype: object

# %% [markdown]
# ### Change the type of the column 'price'. From objet to float
# Strategy: create a vector of Boolean values and use them for indexing the Dataframe

# %%
Data[' price'] != '?'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 200    True
# 201    True
# 202    True
# 203    True
# 204    True
# Name:  price, Length: 205, dtype: bool

# %%
(Data[' price'] == '?').sum()
# Out:
# 4

# %%
Data[Data[' price'] == '?'].T
# Out:
#                           9      44     45         129
#  make                    audi  isuzu  isuzu    porsche
#  fuel-type                gas    gas    gas        gas
#  aspiration             turbo    std    std        std
#  num-of-doors             two    two   four        two
#  body-style         hatchback  sedan  sedan  hatchback
#  drive-wheels             4wd    fwd    fwd        rwd
#  engine-location        front  front  front      front
#  wheel-base              99.5   94.5   94.5       98.4
#  length                 178.2  155.9  155.9      175.7
#  width                   67.9   63.6   63.6       72.3
#  height                  52.0   52.0   52.0       50.5
#  curb-weight             3053   1874   1909       3366
#  engine-type              ohc    ohc    ohc      dohcv
#  num-of-cylinders        five   four   four      eight
#  engine-size              131     90     90        203
#  fuel-system             mpfi   2bbl   2bbl       mpfi
# ...

# %%
Data =Data[Data[' price'] != '?']
print('Shape of the data: ',Data.shape)
# Out:
# Shape of the data:  (201, 24)

# %%
Data[' price'] = Data[' price'].astype('float')

# %%
Data.describe().T.round(2)
# Out:
#                     count      mean      std     min     25%      50%  \
#  wheel-base         201.0     98.80     6.07    86.6    94.5     97.0
#  length             201.0    174.20    12.32   141.1   166.8    173.2
#  width              201.0     65.89     2.10    60.3    64.1     65.5
#  height             201.0     53.77     2.45    47.8    52.0     54.1
#  curb-weight        201.0   2555.67   517.30  1488.0  2169.0   2414.0
#  engine-size        201.0    126.88    41.55    61.0    98.0    120.0
#  compression-ratio  201.0     10.16     4.00     7.0     8.6      9.0
#  city-mpg           201.0     25.18     6.42    13.0    19.0     24.0
#  highway-mpg        201.0     30.69     6.82    16.0    25.0     30.0
#  price              201.0  13207.13  7947.07  5118.0  7775.0  10295.0
#
#                         75%      max
#  wheel-base           102.4    120.9
#  length               183.5    208.1
#  width                 66.6     72.0
#  height                55.5     59.8
# ...

# %% [markdown]
#  ### Excercise: <font color='red'>Correct all the numerical fields</font>
#  In Python, a column in a pandas dataframe with a data type of object could contain either numerical or non-numerical values.

# %%
print(Data.dtypes)
# Out:
#  make                  object
#  fuel-type             object
#  aspiration            object
#  num-of-doors          object
#  body-style            object
#  drive-wheels          object
#  engine-location       object
#  wheel-base           float64
#  length               float64
#  width                float64
#  height               float64
#  curb-weight            int64
#  engine-type           object
#  num-of-cylinders      object
#  engine-size            int64
#  fuel-system           object
#  bore                  object
#  stroke                object
#  compression-ratio    float64
#  horsepower            object
#  peak-rpm              object
#  city-mpg               int64
#  highway-mpg            int64
#  price                float64
# dtype: object

# %%
Data.T.head(24)
# Out:
#                             0            1            2        3        4    \
#  make               alfa-romero  alfa-romero  alfa-romero     audi     audi
#  fuel-type                  gas          gas          gas      gas      gas
#  aspiration                 std          std          std      std      std
#  num-of-doors               two          two          two     four     four
#  body-style         convertible  convertible    hatchback    sedan    sedan
#  drive-wheels               rwd          rwd          rwd      fwd      4wd
#  engine-location          front        front        front    front    front
#  wheel-base                88.6         88.6         94.5     99.8     99.4
#  length                   168.8        168.8        171.2    176.6    176.6
#  width                     64.1         64.1         65.5     66.2     66.4
#  height                    48.8         48.8         52.4     54.3     54.3
# ...

# %% [markdown]
# We visualize the datatypes of the different attributes.
# The attributes that are numerical (from appendix) and have object datatypes are: bore, stroke, horesepower, peak-rpm.

# %%
numerical_cols = Data.select_dtypes(include=['float64', 'int64']).columns.tolist()
print(numerical_cols)
# Out:
# [' wheel-base', ' length', ' width', ' height', ' curb-weight', ' engine-size', ' compression-ratio', ' city-mpg', ' highway-mpg', ' price']

# %%
obj_cols = Data.select_dtypes(include=['object']).columns.tolist()
print(obj_cols)
# Out:
# [' make', ' fuel-type', ' aspiration', ' num-of-doors', ' body-style', ' drive-wheels', ' engine-location', ' engine-type', ' num-of-cylinders', ' fuel-system', ' bore', ' stroke', ' horsepower', ' peak-rpm']

# %%
Data =Data[Data[' bore'] != '?']
Data =Data[Data[' stroke'] != '?']
Data =Data[Data[' horsepower'] != '?']
Data =Data[Data[' peak-rpm'] != '?']

Data[' bore'] = Data[' bore'].astype('float')
Data[' stroke'] = Data[' stroke'].astype('float')
Data[' horsepower'] = Data[' horsepower'].astype('float')
Data[' peak-rpm'] = Data[' peak-rpm'].astype('float')

# %%
Data.describe().T.round(2)
# Out:
#                     count      mean      std      min      25%       50%  \
#  wheel-base         195.0     98.90     6.13    86.60    94.50     97.00
#  length             195.0    174.26    12.48   141.10   166.30    173.20
#  width              195.0     65.89     2.13    60.30    64.05     65.40
#  height             195.0     53.86     2.40    47.80    52.00     54.10
#  curb-weight        195.0   2559.00   524.72  1488.00  2145.00   2414.00
#  engine-size        195.0    127.94    41.43    61.00    98.00    120.00
#  bore               195.0      3.33     0.27     2.54     3.15      3.31
#  stroke             195.0      3.25     0.31     2.07     3.11      3.29
#  compression-ratio  195.0     10.19     4.06     7.00     8.50      9.00
#  horsepower         195.0    103.27    37.87    48.00    70.00     95.00
#  peak-rpm           195.0   5099.49   468.27  4150.00  4800.00   5100.00
#  city-mpg           195.0     25.37     6.40    13.00    19.50     25.00
# ...

# %% [markdown]
# ## Lets see if there is a functional relationship between the variables and price
# * Meaning of the Variables: see Apendix

# %%
Data.columns
# Out:
# Index([' make', ' fuel-type', ' aspiration', ' num-of-doors', ' body-style',
#        ' drive-wheels', ' engine-location', ' wheel-base', ' length', ' width',
#        ' height', ' curb-weight', ' engine-type', ' num-of-cylinders',
#        ' engine-size', ' fuel-system', ' bore', ' stroke',
#        ' compression-ratio', ' horsepower', ' peak-rpm', ' city-mpg',
#        ' highway-mpg', ' price'],
#       dtype='object')

# %%
Data.columns.values
# Out:
# array([' make', ' fuel-type', ' aspiration', ' num-of-doors',
#        ' body-style', ' drive-wheels', ' engine-location', ' wheel-base',
#        ' length', ' width', ' height', ' curb-weight', ' engine-type',
#        ' num-of-cylinders', ' engine-size', ' fuel-system', ' bore',
#        ' stroke', ' compression-ratio', ' horsepower', ' peak-rpm',
#        ' city-mpg', ' highway-mpg', ' price'], dtype=object)

# %% [markdown]
# ## Lets' see the dependence between variables

# %%
Data[' price'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
Data[[' price',' city-mpg']].plot()
Data.plot.scatter(figsize=(10,6),y=' price',x=' city-mpg')
Data.plot.scatter(figsize=(10,6),y=' price',x=' engine-size')
Data.hist(figsize=(10,10),bins = 25)
# Out:
# array([[<AxesSubplot:title={'center':' wheel-base'}>,
#         <AxesSubplot:title={'center':' length'}>,
#         <AxesSubplot:title={'center':' width'}>,
#         <AxesSubplot:title={'center':' height'}>],
#        [<AxesSubplot:title={'center':' curb-weight'}>,
#         <AxesSubplot:title={'center':' engine-size'}>,
#         <AxesSubplot:title={'center':' bore'}>,
#         <AxesSubplot:title={'center':' stroke'}>],
#        [<AxesSubplot:title={'center':' compression-ratio'}>,
#         <AxesSubplot:title={'center':' horsepower'}>,
#         <AxesSubplot:title={'center':' peak-rpm'}>,
#         <AxesSubplot:title={'center':' city-mpg'}>],
#        [<AxesSubplot:title={'center':' highway-mpg'}>,
#         <AxesSubplot:title={'center':' price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
#  ### Excercise: <font color='red'>Explore the functional dependencies between features and target (price) </font>
#  1. Give a qualitative shape of the dependency.
#  2. Explain why you choose a given functional dependency. Relate your explanation to the histogram of the data.
#  3. Explore and begin learning  the visualization features of  Pandas.
#  https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization
#  3. Finally, propose (by hand), an intuitive and first approach f(x) of the prediction of price. I.e. y = sum of functions of each feature

# %% [markdown]
# In order to give a qualitative shape of the dependency of numerical variables with price we are going to explicitly describe the function type and let the scipy optimizer fit our parameters so the error is minimized. This will be done only with a pair of examples and the others will be done by hand.
#
# - For the first dependency an exponential delay or a power law could explain well the reltionship. Makes sense that very expensive cars, like supercars, have a much higher city consumption. This also matches with histograms of city consumption and price. There are very few cars that consume a lot and that are very expensive while the majority of them are affordable and have a mid-range (around 20-25 miles/gallon) city consumption.
# - The second one is clearly linear. The bigger the engine size, the more expensive the car is. This could have been expected since the histogram of engine size and price has the same shape. Linear relationships are characterized by histograms of both variables having the same shape.

# %% [markdown]
# By analysis of the plots, one can tell the data of city-mpg is not ordered. In order to do a fitting it is cruciat for it to be.

# %%
import matplotlib.pyplot as plt
import numpy as np

xdata = Data[' city-mpg']
ydata = Data[' price']

# delete all nans values
nan_indices_1 = np.where(np.isnan(xdata))
nan_indices_2 = np.where(np.isnan(ydata))

# use union1d to join the arrays without repetition
joined_arr = np.union1d(nan_indices_1, nan_indices_2)

xdata = np.delete(np.array(xdata), joined_arr)
ydata = np.delete(np.array(ydata), joined_arr)

# solve index problems from deleting rows previously by reindexing
if len(joined_arr)!= 0:
    new_index = range(len(ydata))
    xdata = xdata.reindex(new_index)
    ydata = ydata.reindex(new_index)

# get indices that would sort x in ascending order
sort_indices = np.argsort(xdata)

# sort both x and y using the same indices
x_sorted = xdata[sort_indices]
y_sorted = ydata[sort_indices]

# %%
from scipy.optimize import curve_fit
from scipy.optimize import OptimizeWarning
import warnings


def func_a(x, a, b):
    return a * x ** -b

def func_b(x, a, b, c):
    return a * np.exp(-b * (x - c))


xdata = Data[' city-mpg']
ydata = Data[' price']

with warnings.catch_warnings():
    warnings.simplefilter('ignore', OptimizeWarning)
    popt_a, pcov = curve_fit(func_a, xdata, ydata)
    popt_b, pcov = curve_fit(func_b, xdata, ydata, p0 = [2.98639842e+04, 9.67477725e-02,15])
Data.plot.scatter(figsize=(10,6),y=' price',x=' city-mpg', label='Data')
plt.plot(x_sorted, func_a(x_sorted, *popt_a), 'g-', label='Fit_power')
plt.plot(x_sorted, func_b(x_sorted, *popt_b), 'r-', label='Fit_exponential')
plt.legend()
plt.show()

# %% [markdown]
# The preprocessing of the data is not as important as the last case when trying to fit due to the simplicity of a linear fitting.

# %%
def func_b(x, a, b):
    return a + b * x
xdata = Data[' engine-size']
ydata = Data[' price']
popt, pcov = curve_fit(func_b, xdata, ydata)
Data.plot.scatter(figsize=(10,6),y=' price',x=' engine-size', label='Data')
plt.plot(xdata, func_b(xdata, *popt), 'r-', label='Fit')
plt.legend()
plt.show()

# %%
# define target feature
target_feature = ' price'

# loop over all numerical features (excluding the target feature)
numerical_cols = Data.select_dtypes(include=['float64', 'int64']).columns.tolist()

# create a figure and axis object
fig, axs = plt.subplots(nrows=len(numerical_cols)-1, ncols=2, figsize=(10, 40)) #-1 since no need to plot price vs price

i = 0
for feature in (numerical_cols):
    if feature != target_feature:
        # plot the x-y scatter plot
        axs[i, 0].scatter(Data[feature], Data[target_feature])
        axs[i, 0].set_xlabel(feature)
        axs[i, 0].set_ylabel(target_feature)

        # plot the histogram of the feature
        axs[i, 1].hist(Data[feature], bins=20)
        axs[i, 1].set_xlabel(feature)
        i += 1
        
plt.tight_layout()
plt.show()

# %%
Data[' price'].hist(bins = 25)
plt.xlabel("price")
# Out:
# Text(0.5, 0, 'price')

# %%
from IPython.display import Image
Image(filename='pp1.png', width=600, height=300)

# %% [markdown]
# From this dependencis we can now write an intuitive and first approach y=f(x) wich relates features x with target y, price.
# - Let f(Weel base) be the fitted to price quadratic expression.
# - Let g(length) be the fitted to price exponential expression.
# - Let h(width) be the fitted to price quadratic expression.
# - Let k(curb weight) be the fitted to price quadratic expression.
# - Let l(engine size) be the fitted to price linear expression.
# - Let t(horsepower) be the fitted to price quadratic expression.
# - Let q(city mpg) be the fitted to price exponential expression.
# - Let p(highway mpg) be the fitted to price exponential expression.
#
# A first approach to y would be to make a ponderated sum of all this expressions. $w_i$ be the weights of this ponderation. This weights $w_i$ should be normalized and would depend on the importance of the feature over the target. Thus:
# $$
# y = w_1*f(Weel base)+w_2*g(length)+w_3*h(width)+w_4*k(curb weight)+w_5*l(engine size)+w_6*t(horsepower)+w_7*q(city mpg)+w_8*p(highway mpg)
# $$

# %% [markdown]
# A first approach to these wegihts would be the normalization of the absolute values of the correlation matrix.

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,10)})
sns.heatmap(Data.corr(), annot=True, fmt='.2f', linewidth=2)

Data.corr()[' price']
# Out:
#  wheel-base           0.585793
#  length               0.695331
#  width                0.754273
#  height               0.138291
#  curb-weight          0.835729
#  engine-size          0.888942
#  bore                 0.546873
#  stroke               0.093746
#  compression-ratio    0.069500
#  horsepower           0.811027
#  peak-rpm            -0.104333
#  city-mpg            -0.702685
#  highway-mpg         -0.715590
#  price                1.000000
# Name:  price, dtype: float64

# %% [markdown]
# ### Excercise: <font color='red'> Repeat the practice with the database **Wine Quality** target (**quality**) </font>

# %%
File = "winequality-red.csv"
Filename = os.path.join(os.getcwd(),'Data',File)
print(f'Filename with path: \n {Filename}')
Data = pd.read_csv(Filename)
Data.head().T
# Out:
# Filename with path:
#  C:\Users\raulc\Desktop\Master\Q2\ML\FirstPractice\Data\winequality-red.csv
#                             0        1       2       3        4
# fixed acidity          7.4000   7.8000   7.800  11.200   7.4000
# volatile acidity       0.7000   0.8800   0.760   0.280   0.7000
# citric acid            0.0000   0.0000   0.040   0.560   0.0000
# residual sugar         1.9000   2.6000   2.300   1.900   1.9000
# chlorides              0.0760   0.0980   0.092   0.075   0.0760
# free sulfur dioxide   11.0000  25.0000  15.000  17.000  11.0000
# total sulfur dioxide  34.0000  67.0000  54.000  60.000  34.0000
# density                0.9978   0.9968   0.997   0.998   0.9978
# pH                     3.5100   3.2000   3.260   3.160   3.5100
# sulphates              0.5600   0.6800   0.650   0.580   0.5600
# alcohol                9.4000   9.8000   9.800   9.800   9.4000
# quality                5.0000   5.0000   5.000   6.000   5.0000

# %%
print(Data.dtypes)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# This dataset already has numeric features declared with it's proper datatype.
# However the first thing that comes into our mind is that the target feature is no longer continuos, it is discrete (based on the appendix).

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Since there are no null entries, we don't need to deal with missing values.

# %%
Data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# define target feature
target_feature = 'quality'

# loop over all numerical features (excluding the target feature)
numerical_cols = Data.select_dtypes(include=['float64', 'int64']).columns.tolist()

# create a figure and axis object
fig, axs = plt.subplots(nrows=len(numerical_cols)-1, ncols=2, figsize=(10, 40)) #-1 since no need to plot price vs price

i = 0
for feature in (numerical_cols):
    if feature != target_feature:
        # plot the x-y scatter plot
        axs[i, 0].scatter(Data[feature], Data[target_feature])
        axs[i, 0].set_xlabel(feature)
        axs[i, 0].set_ylabel(target_feature)

        # plot the histogram of the feature
        axs[i, 1].hist(Data[feature], bins=20)
        axs[i, 1].set_xlabel(feature)
        i += 1
        
plt.tight_layout()
plt.show()

# %% [markdown]
# Since the target is discrete, these kind of plots don't help us to state the shape of the dependency. We will need barplots where we can see the effects of one variables over the target.
#
# We will use the barplot of seaborn package, which has the following description in its documentation. As in a classification problem, we will plot our target variable in the x axis.
# Show point estimates and errors as rectangular bars.
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars. Bar plots include 0 in the quantitative axis range, and they are a good choice when 0 is a meaningful value for the quantitative variable, and you want to make comparisons against it.

# %%
# define target feature
target_feature = 'quality'

# loop over all numerical features (excluding the target feature)
numerical_cols = Data.select_dtypes(include=['float64', 'int64']).columns.tolist()

# create a figure and axis object
fig, axs = plt.subplots(nrows=len(numerical_cols)-1, ncols=2, figsize=(10, 40)) #-1 since no need to plot price vs price
warnings.filterwarnings('ignore', message='Pass the following variables as keyword args: x, y.*')
i = 0
for feature in (numerical_cols):
    if feature != target_feature:
        # plot the x-y scatter plot
        sns.barplot(Data[target_feature],Data[feature],ax = axs[i, 0], palette="GnBu_d")
        axs[i, 0].set_xlabel(target_feature)
        axs[i, 0].set_ylabel(feature)

        # plot the histogram of the feature
        axs[i, 1].hist(Data[feature], bins=20)
        axs[i, 1].set_xlabel(feature)
        i += 1
        
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(Data.quality,bins=6,alpha=0.5,histtype='bar',ec='black')
plt.title('Distribution of the Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The above plot shows the distribution of the quality of the wine in the dataset, and represents that most of the wine is of average quality i.e. quality ranging from 5-7 .

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.heatmap(Data.corr(), annot=True, fmt='.2f', linewidth=2)

Data.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# From the correlation matrix we see that alchohol, volitile acidity are the most correlated variables with quality. Also sulphates, citric acidity, total sulphur dioxide and density have less but significant impact on quality.
#
# Now we explore the functional dependencies between features and target, in this case wine quality.

# %%
from IPython.display import Image
Image(filename='pp2.png', width=600, height=300)

# %% [markdown]
# From this dependencis we can now write an intuitive and first approach y=f(x) wich relates features x with target y, price.
# - Let f(volatile acidity) be the fitted to quality exponential expression.
# - Let g(citric acid) be the fitted to quality quadratic expression.
# - Let h(chlorides) be the fitted to quality linear expression.
# - Let k(free sulfur dioxide) be the fitted to quality quadratic expression.
# - Let l(total sulfur dioxide) be the fitted to quality linear expression.
# - Let t(pH) be the fitted to quality linear expression.
# - Let q(sulphates) be the fitted to quality linear expression.
# - Let p(alcohol) be the fitted to quality exponential expression.
#
# A first approach to y would be to make a ponderated sum of all this expressions. $w_i$ be the weights of this ponderation. This weights $w_i$ should be normalized and would depend on the importance of the feature over the target. Thus:
# $$
# y = w_1*f(volatile acidity)+w_2*g(citric acid)+w_3*h(chlorides)+w_4*k(free sulfur dioxide)+w_5*l(total sulfur dioxide)+w_6*t(pH)+w_7*q(sulphates)+w_8*p(alcohol)
# $$

# %% [markdown]
# ## Appendix:
# ### Description of the variables
#  1. make: The name of the produces of the car (a factor).
#  - alfa-romero, audi, bmw, chevrolet, dodge, honda,  isuzu, jaguar, mazda, mercedes-benz, mercury,mitsubishi, nissan, peugot, plymouth, porsche,renault, saab, subaru, toyota, volkswagen, volvo
#
# 2. fuel-type: The type of fuel used by the car, either diesel or gas (a factor).
#  - diesel, gas.
# 3. aspiration:	Type of aspiration of fuel in the motor
# - std, turbo.
# 4. num-of-doors: The number of passenger doors, either two or four (a factor).
#  - four, two.
# 5. body-styleThe type of the car (a factor).
# - hardtop, wagon, sedan, hatchback, convertible.
# 6. drive-wheels: The wheels powered by the engine (a factor).
# - 4wd, fwd, rwd.
# 7. engine-location: The location in the car of the engine (a factor).
# - front, rear.
# 8. wheel-base: The distance between the centers of the front and rear wheels in inches (numeric).
# - continuous from 86.6 120.9.
# 9. length: The length of the body of the car in inches (numeric).
# - continuous from 141.1 to 208.1.
# 10. width: The width of the body of the car in inches (numeric).
# - continuous from 60.3 to 72.3.
# 11. height: The height of the car in inches (numeric).
# - continuous from 47.8 to 59.8.
# 12. curb-weight: The total weight in pounds of a vehicle with standard equipment and a full tank of fuel, but with no passengers or cargo (numeric).
# - continuous from 1488 to 4066.
# 13. engine-type: Mechanical Feature  (numeric).
# - dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 14. num-of-cylinders:: Mechanical Feature  (a factor).
# - eight, five, four, six, three, twelve, two.
# 15. engine-size: The volume swept by all the pistons inside the cylinders in cubic inches (numeric).
#  - continuous from 61 to 326.
# 16. fuel-system: Mechanical Feature  (a factor).
# - 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 17. bore: Mechanical Feature  (numeric).
# - continuous from 2.54 to 3.94.
# 18. stroke: Mechanical Feature  (numeric).
# - continuous from 2.07 to 4.17.
# 19. compression-ratio: Mechanical Feature  (numeric).
# - continuous from 7 to 23.
# 20. horsepower: The power of the engine in horsepowers (numeric).
# - continuous from 48 to 288.
# 21. peak-rpm: The top speed of the engine in rounds-per-minute (numeric).
# - continuous from 4150 to 6600.
# 22. city-mpg: The fuel consumption of the car in city driving conditions, measured as miles per gallon of fuel (numeric).
# - continuous from 13 to 49.
# 23. highway-mpg: The fuel consumption of the car in highway driving conditions, measured as miles per gallon of fuel (numeric).
# - continuous from 16 to 54.
# 24. price: The retail price of the car in US Dollars (numeric).
# - continuous from 5118 to 45400.

# %% [markdown]
# ## Description of variables: Wine  quality
# ### Input variables (based on physicochemical tests):
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol
# Output variable (based on sensory data):
# 12. quality (score between 0 and 10)
